# %%
import pandas as pd 

# final = 'data/TOTAL LIWC-22 - 4 dimensoes.csv'
final = 'data/2 TODAS AS CVS LIWC-22 - 4 dimensoes.csv'

df_liwc = pd.read_csv(final)
df_liwc.head()

#Analise do dataset final
print("Num of PRs:{}\nTotal number of comments:{}\nAverage number of comments".format(df_liwc['pr_id'].unique().shape[0], df_liwc.loc[df_liwc['type']=='comment'].shape[0]))

# Num of PRs:3601
# Total number of comments:2477
# Average number of comments:0.688

# Num of PRs:3539
# Total number of comments:2472
# Average number of comments:0.698

# Num of PRs:4105
# Total number of comments:2468
# Average number of comments:0.601
# Out:
# Num of PRs:4105
# Total number of comments:2468
# Average number of comments
